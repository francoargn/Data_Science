# %% [markdown]
# ## Prediccion del precio del Bitcoin y ETH, utilizando la libreria Prophet de Facebook

# %% [markdown]
# El historico de precio utilizados es de la exchange Bincance, dicho dataset es extraido de la pagina **www.cryptodatadownload.com/data/**

# %% [markdown]
# Para las predicciones se utiliza la libreria Prophet de facebook, cuya documentacion esta adjunta en el repositorio **www.facebook.github.io/prophet**

# %% [markdown]
# ## Importamos las librerias correspondientes

# %%
import pandas as pd  
from fbprophet import Prophet

# %%
btc= pd.read_csv('btc_price_binance.csv') 
btc.tail()
# Out:
#               unix        date    symbol     open     high      low    close  \
# 1234  1.503274e+09  2017-08-21  BTC/USDT  4086.29  4119.62  3911.79  4016.00
# 1235  1.503187e+09  2017-08-20  BTC/USDT  4139.98  4211.08  4032.62  4086.29
# 1236  1.503101e+09  2017-08-19  BTC/USDT  4108.37  4184.69  3850.00  4139.98
# 1237  1.503014e+09  2017-08-18  BTC/USDT  4285.08  4371.52  3938.77  4108.37
# 1238  1.502928e+09  2017-08-17  BTC/USDT  4469.93  4485.39  4200.74  4285.08
#
#       Volume BTC  Volume USDT  tradecount
# 1234      685.12   2770592.06         NaN
# 1235      463.54   1915636.35         NaN
# 1236      371.15   1508239.39         NaN
# 1237     1178.07   4994493.56         NaN
# 1238      647.86   2812379.11         NaN

# %% [markdown]
# ## Importamos los datos del tiempo de la libreria pandas

# %%
from pandas import to_datetime

# %% [markdown]
# La libreria prophet exige trabajar con dos columnas, una donde esta la fecha (ds) y otra donde este la caracteristica a predecir (y). La columna ds debe tener el formato esperado por pandas, idealmente AAAA-MM-DD

# %%
df=pd.DataFrame(btc.close) # Creamos el dataframe con los precios de cierre del btc
df.columns=['y'] # Creamos la columna y, que en este caso sera el precio
df['ds']=to_datetime(btc.date) # Creamos la columna con ds con la fechas, formato esperado por pandas 
df.reset_index( drop=True, inplace=True) # Reseteamos los datos
print(df.shape) 
df.head()
# Out:
# (1239, 2)
#           y         ds
# 0  32221.92 2021-01-05
# 1  31988.71 2021-01-04
# 2  33000.05 2021-01-03
# 3  32178.33 2021-01-02
# 4  29331.69 2021-01-01

# %% [markdown]
# Ajuste del modelo y luego lo entrenamos, segun lo explicado en la libreria

# %% [markdown]
# Luego de varias predicciones se decidio tomar los datos apartir del año 2019, ya que el modelo tomaba los valores bajos de los años 2018 y 2017

# %%
df.loc[(df['ds'] < '2019-01-01'), 'y'] = None # Se toman los valores apartir del año 2019
m = Prophet(yearly_seasonality=True, daily_seasonality= True).fit(df)
#fig = m.plot(m.predict(future))

# %% [markdown]
# Se agrega al dataframe la cantidad de fechas a predecir

# %%
future=m.make_future_dataframe(periods=31) 
future.tail()
# Out:
#              ds
# 1264 2021-02-01
# 1265 2021-02-02
# 1266 2021-02-03
# 1267 2021-02-04
# 1268 2021-02-05

# %% [markdown]
# Se realiza la prediccion. Los datos predichos se encontraran en la columna de yhat, junto al los intervalos de incertidumbre

# %%
forecast=m.predict(future) 
forecast[['ds','yhat','yhat_lower','yhat_upper']].tail()
# Out:
#              ds          yhat    yhat_lower    yhat_upper
# 1264 2021-02-01  32808.580014  31765.050648  33871.475221
# 1265 2021-02-02  32977.558224  31875.271553  33979.266873
# 1266 2021-02-03  33181.796874  32105.559581  34279.487051
# 1267 2021-02-04  33312.876929  32235.730598  34285.744062
# 1268 2021-02-05  33528.069654  32400.331842  34499.276270

# %% [markdown]
# Se grafica los pronosticos que se obtuvieron

# %%
fig1=m.plot(forecast)

# %%
fig2=m.plot_components(forecast)

# %% [markdown]
# ## Ethereum

# %%
eth= pd.read_csv('eth_price.csv') 
eth.tail()
# Out:
#               unix        date    symbol    open    high     low   close  \
# 1234  1.503274e+09  2017-08-21  ETH/USDT  299.10  346.52  294.60  323.29
# 1235  1.503187e+09  2017-08-20  ETH/USDT  290.91  300.53  282.85  299.10
# 1236  1.503101e+09  2017-08-19  ETH/USDT  293.96  299.90  278.00  290.91
# 1237  1.503014e+09  2017-08-18  ETH/USDT  302.00  311.79  283.94  293.96
# 1238  1.502928e+09  2017-08-17  ETH/USDT  303.61  312.18  298.21  302.00
#
#       Volume ETH  Volume USDT  tradecount
# 1234     5134.54   1661944.36         NaN
# 1235     2469.49    730800.66         NaN
# 1236     2140.08    618248.58         NaN
# 1237     9392.79   2815460.24         NaN
# 1238     6155.32   1890017.53         NaN

# %%
df=pd.DataFrame(eth.close) # Creamos el dataframe con los precios de cierre del btc
df.columns=['y'] # Creamos la columna y, que en este caso sera el precio
df['ds']=to_datetime(eth.date) # Creamos la columna con ds con la fechas, formato esperado por pandas 
df.reset_index( drop=True, inplace=True) # Reseteamos los datos
print(df.shape) 
df.head()
# Out:
# (1239, 2)
#          y         ds
# 0  1062.40 2021-01-05
# 1  1041.43 2021-01-04
# 2   978.28 2021-01-03
# 3   774.56 2021-01-02
# 4   728.91 2021-01-01

# %%
df.loc[(df['ds'] < '2019-01-01'), 'y'] = None
m = Prophet(daily_seasonality=True).fit(df)
#fig = m.plot(m.predict(future))

# %%
future=m.make_future_dataframe(periods=31) 
future.tail()
# Out:
#              ds
# 1264 2021-02-01
# 1265 2021-02-02
# 1266 2021-02-03
# 1267 2021-02-04
# 1268 2021-02-05

# %%
forecast=m.predict(future) 
forecast[['ds','yhat','yhat_lower','yhat_upper']].tail()
# Out:
#              ds        yhat  yhat_lower  yhat_upper
# 1264 2021-02-01  911.690840  870.081750  950.940156
# 1265 2021-02-02  918.083056  876.418116  957.337087
# 1266 2021-02-03  923.835445  889.077940  962.007971
# 1267 2021-02-04  929.994802  890.817715  974.366436
# 1268 2021-02-05  939.321301  897.251146  979.768324

# %%
fig1=m.plot(forecast)

# %%
fig2=m.plot_components(forecast)
