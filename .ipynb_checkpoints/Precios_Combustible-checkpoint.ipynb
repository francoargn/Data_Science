# %% [markdown]
# ## Precios de Combustibles

# %%
import warnings
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df=pd.read_csv('Precios_Combustible.csv')

# %%
df.shape
# Out:
# (35978, 19)

# %%
df.head()
# Out:
#   indice_tiempo  idempresa           cuit               empresa  \
# 0       2017-03       1376  33-64337382-9  10 DE SETIEMBRE S.A.
# 1       2017-03       1376  33-64337382-9  10 DE SETIEMBRE S.A.
# 2       2017-04       8943  30-71251168-7              1913 SRL
# 3       2017-04       8943  30-71251168-7              1913 SRL
# 4       2017-04       8943  30-71251168-7              1913 SRL
#
#           direccion          localidad     provincia     region  idproducto  \
# 0   Av. Mosconi 299  LOMAS DEL MIRADOR  BUENOS AIRES   PAMPEANA           6
# 1   Av. Mosconi 299  LOMAS DEL MIRADOR  BUENOS AIRES   PAMPEANA           6
# 2  Julio A Roca 715   GOBERNADOR COSTA        CHUBUT  PATAGONIA          19
# 3  Julio A Roca 715   GOBERNADOR COSTA        CHUBUT  PATAGONIA          19
# 4  Julio A Roca 715   GOBERNADOR COSTA        CHUBUT  PATAGONIA          21
#
#           producto  idtipohorario tipohorario  precio       fecha_vigencia  \
# 0              GNC              2      Diurno    8.79  2017-03-27 10:38:00
# 1              GNC              3    Nocturno    8.79  2017-03-27 10:38:00
# 2  Gas Oil Grado 2              2      Diurno   14.96  2017-04-06 20:51:00
# 3  Gas Oil Grado 2              3    Nocturno   14.96  2017-04-06 20:51:00
# 4  Gas Oil Grado 3              2      Diurno   16.75  2017-04-06 20:52:00
#
#    idempresabandera empresabandera    latitud   longitud  \
# 0                 1         BLANCA -34.658476 -58.529443
# 1                 1         BLANCA -34.658476 -58.529443
# 2                26          AXION -44.050662 -70.583041
# 3                26          AXION -44.050662 -70.583041
# 4                26          AXION -44.050662 -70.583041
#
#                                              geojson
# 0  {"type":"Point","coordinates":[-58.529443,-34....
# 1  {"type":"Point","coordinates":[-58.529443,-34....
# 2  {"type":"Point","coordinates":[-70.583041,-44....
# 3  {"type":"Point","coordinates":[-70.583041,-44....
# 4  {"type":"Point","coordinates":[-70.583041,-44....

# %%
df.value_counts().index
# Out:
# MultiIndex([('2020-07', 8952, '33-71518900-9',               'ADD SRL', ...),
#             ('2019-12', 3570, '30-51618667-0', 'DEHEZA S.A.I.C.I.F.I.', ...),
#             ('2019-12', 3559, '30-51618667-0',    'DEHEZA S.A.I.C.F.I', ...),
#             ('2019-12', 3559, '30-51618667-0',    'DEHEZA S.A.I.C.F.I', ...),
#             ('2019-12', 3559, '30-51618667-0',    'DEHEZA S.A.I.C.F.I', ...),
#             ('2019-12', 3559, '30-51618667-0',    'DEHEZA S.A.I.C.F.I', ...),
#             ('2019-12', 3568, '30-51618667-0',   'DEHEZA S.A.I.C.F.I.', ...),
#             ('2019-12', 3568, '30-51618667-0',   'DEHEZA S.A.I.C.F.I.', ...),
#             ('2019-12', 3568, '30-51618667-0',   'DEHEZA S.A.I.C.F.I.', ...),
#             ('2019-12', 3568, '30-51618667-0',   'DEHEZA S.A.I.C.F.I.', ...),
#             ...
#             ('2020-03',  842, '30-67877449-5',    'OPESSA ACA GALARZA', ...),
#             ('2020-03',  842, '30-67877449-5',    'OPESSA ACA GALARZA', ...),
#             ('2020-03',  842, '30-67877449-5',    'OPESSA ACA GALARZA', ...),
#             ('2020-03',  842, '30-67877449-5',    'OPESSA ACA GALARZA', ...),
#             ('2020-03',  843, '30-67877449-5',      'OPESSA ACA JUNIN', ...),
#             ('2020-03',  843, '30-67877449-5',      'OPESSA ACA JUNIN', ...),
#             ('2020-03',  843, '30-67877449-5',      'OPESSA ACA JUNIN', ...),
#             ('2020-03',  843, '30-67877449-5',      'OPESSA ACA JUNIN', ...),
#             ('2020-03',  844, '30-67877449-5',    'OPESSA ACA LAVALLE', ...),
#             ('2016-04', 6365, '30-70751747-2',            'SERIGAS SH', ...)],
#            names=['indice_tiempo', 'idempresa', 'cuit', 'empresa', 'direccion', 'localidad', 'provincia', 'region', 'idproducto', 'producto', 'idtipohorario', 'tipohorario', 'precio', 'fecha_vigencia', 'idempresabandera', 'empresabandera', 'latitud', 'longitud', 'geojson'], length=32557)

# %%
df.isnull().sum()
# Out:
# indice_tiempo          0
# idempresa              0
# cuit                   0
# empresa                0
# direccion             14
# localidad              0
# provincia              0
# region              3383
# idproducto             0
# producto               0
# idtipohorario          0
# tipohorario            0
# precio                 0
# fecha_vigencia         0
# idempresabandera       0
# empresabandera         0
# latitud               98
# longitud              98
# geojson               98
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35978 entries, 0 to 35977
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   indice_tiempo     35978 non-null  object
#  1   idempresa         35978 non-null  int64
#  2   cuit              35978 non-null  object
#  3   empresa           35978 non-null  object
#  4   direccion         35964 non-null  object
#  5   localidad         35978 non-null  object
#  6   provincia         35978 non-null  object
#  7   region            32595 non-null  object
#  8   idproducto        35978 non-null  int64
#  9   producto          35978 non-null  object
#  10  idtipohorario     35978 non-null  int64
#  11  tipohorario       35978 non-null  object
#  12  precio            35978 non-null  float64
#  13  fecha_vigencia    35978 non-null  object
#  14  idempresabandera  35978 non-null  int64
#  15  empresabandera    35978 non-null  object
#  16  latitud           35880 non-null  float64
#  17  longitud          35880 non-null  float64
#  18  geojson           35880 non-null  object
# dtypes: float64(3), int64(4), object(12)
# memory usage: 5.2+ MB

# %%
plt.figure(figsize=(20,10))
sns.countplot(y=df['empresabandera'])
plt.show()

# %%
df_t=df[df.provincia.isin(['TUCUMAN','SANTIAGO DEL ESTERO','CATAMARCA','SALTA','JUJUY','CORDOBA'])]

# %%
df_t.shape
# Out:
# (7206, 19)

# %%
df_bs=df[df.provincia.isin(['BUENOS AIRES'])] 
df_bs.shape
# Out:
# (13438, 19)

# %%
plt.figure(figsize=(15,6))
plt.subplot(1,3,1)
sns.boxplot(y=df_t['precio']) 
plt.title('Distribucion precio NOA') 
plt.subplot(1,3,2)
sns.boxplot(y=df_bs['precio']) 
plt.title('Distribucion Precio Buenos Aires') 
plt.subplot(1,3,3)
sns.boxplot(y=df['precio'])
plt.title('Distribucion Precio Argentina')
plt.show()

# %%
def elimino_valores_atipicos(df_6):
    Q1=df.quantile(0.25)
    Q3=df.quantile(0.75)
    IQR=Q3-Q1

    df_filtrado= df[~((df_6 < (Q1 - 1.5 * IQR)) |(df > (Q3 + 1.5 * IQR))).any(axis=1)]

    return df_filtrado

# %%
df=elimino_valores_atipicos(df)

# %%
df_t['precio'].mean()
# Out:
# 53.921345545378855

# %%
df_t.describe()
# Out:
#         idempresa   idproducto  idtipohorario       precio  idempresabandera  \
# count  7206.00000  7206.000000    7206.000000  7206.000000       7206.000000
# mean   5068.03053    10.544546       2.500000    53.921346          5.788232
# std    2964.61060     8.379738       0.500035    14.951625          7.800593
# min     105.00000     2.000000       2.000000     8.990000          1.000000
# 25%    2488.25000     3.000000       2.000000    53.390000          2.000000
# 50%    4998.00000     6.000000       2.500000    59.490000          2.000000
# 75%    7727.00000    19.000000       3.000000    63.990000          4.000000
# max    9869.00000    21.000000       3.000000    69.990000         29.000000
#
#            latitud     longitud
# count  7170.000000  7170.000000
# mean    -29.698052   -64.296425
# std       3.057381     0.980289
# min     -34.903929   -68.760231
# 25%     -31.720810   -65.156670
# 50%     -31.347220   -64.263279
# 75%     -27.038890   -64.020377
# max     -22.055820   -58.391527

# %%
df_bs.describe()
# Out:
#           idempresa    idproducto  idtipohorario        precio  \
# count  13438.000000  13438.000000   13438.000000  13438.000000
# mean    4821.558863     10.600238       2.499851     53.630095
# std     2894.213051      8.411119       0.500019     14.033017
# min      102.000000      2.000000       2.000000      7.000000
# 25%     2085.000000      3.000000       2.000000     53.190000
# 50%     4741.000000      6.000000       2.000000     56.930000
# 75%     7391.000000     19.000000       3.000000     63.540000
# max     9868.000000     21.000000       3.000000     69.990000
#
#        idempresabandera       latitud      longitud
# count      13438.000000  13430.000000  13430.000000
# mean           8.061542    -35.348312    -59.105056
# std            9.613287      1.384129      1.350285
# min            1.000000    -40.800308    -66.847852
# 25%            2.000000    -35.627690    -59.500150
# 50%            3.000000    -34.740776    -58.608905
# 75%           17.000000    -34.563043    -58.389508
# max           29.000000    -29.413973    -56.679214

# %%
df.describe()
# Out:
#           idempresa    idproducto  idtipohorario        precio  \
# count  22154.000000  22154.000000   22154.000000  22154.000000
# mean    4530.430080     11.200822       2.499910     59.263930
# std     2926.589971      8.782848       0.500011      5.661502
# min      104.000000      2.000000       2.000000     36.990000
# 25%     1680.000000      2.000000       2.000000     54.590000
# 50%     4159.000000      3.000000       2.000000     59.490000
# 75%     7307.000000     19.000000       3.000000     64.200000
# max     9869.000000     21.000000       3.000000     69.990000
#
#        idempresabandera       latitud      longitud
# count      22154.000000  22060.000000  22060.000000
# mean           2.478740    -33.238278    -61.324527
# std            1.112392      2.877142      3.428409
# min            1.000000    -39.514240    -71.049582
# 25%            2.000000    -34.732736    -64.128660
# 50%            2.000000    -33.736548    -60.567160
# 75%            3.000000    -31.534890    -58.536520
# max            7.000000    -26.476965    -54.112920

# %%
df.provincia.unique()
# Out:
# array(['SAN LUIS', 'BUENOS AIRES', 'SANTA FE', 'ENTRE RIOS', 'RIO NEGRO',
#        'CHACO', 'SANTIAGO DEL ESTERO', 'MENDOZA', 'CATAMARCA', 'CORDOBA',
#        'MISIONES', 'CORRIENTES', 'LA PAMPA', 'CAPITAL FEDERAL', 'TUCUMAN',
#        'NEUQUEN', 'SAN JUAN', 'LA RIOJA', 'JUJUY', 'FORMOSA'],
#       dtype=object)

# %% [markdown]
# ### Damos formato de tiempo a la columna "Fecha_Vigencia"

# %%
df.fecha_vigencia=pd.to_datetime(df.fecha_vigencia)
df
# Out:
#       indice_tiempo  idempresa           cuit                         empresa  \
# 10          2019-12       1284  30-56342987-5           25 DE MAYO SRL (EESS)
# 11          2019-12       1284  30-56342987-5           25 DE MAYO SRL (EESS)
# 12          2019-12       1284  30-56342987-5           25 DE MAYO SRL (EESS)
# 13          2019-12       1284  30-56342987-5           25 DE MAYO SRL (EESS)
# 16          2020-03       1284  30-56342987-5           25 DE MAYO SRL (EESS)
# ...             ...        ...            ...                             ...
# 35973       2020-03       7895  30-71221281-7                  LIQUID GAS S.A
# 35974       2020-03       7895  30-71221281-7                  LIQUID GAS S.A
# 35975       2020-03       7895  30-71221281-7                  LIQUID GAS S.A
# 35976       2020-04       2243  30-53852511-8  ALFREDO BRUGNOLI E HIJOS S.C.C
# 35977       2020-04       2243  30-53852511-8  ALFREDO BRUGNOLI E HIJOS S.C.C
#
#             direccion               localidad     provincia    region  \
# 10     25 DE MAYO 675          VILLA MERCEDES      SAN LUIS      CUYO
# 11     25 DE MAYO 675          VILLA MERCEDES      SAN LUIS      CUYO
# 12     25 DE MAYO 675          VILLA MERCEDES      SAN LUIS      CUYO
# 13     25 DE MAYO 675          VILLA MERCEDES      SAN LUIS      CUYO
# 16     25 DE MAYO 675          VILLA MERCEDES      SAN LUIS      CUYO
# ...               ...                     ...           ...       ...
# 35973             NaN                   MORON  BUENOS AIRES  PAMPEANA
# 35974             NaN                   MORON  BUENOS AIRES  PAMPEANA
# 35975             NaN                   MORON  BUENOS AIRES  PAMPEANA
# 35976             NaN  CONCEPCION DEL BERMEJO         CHACO       NEA
# 35977             NaN  CONCEPCION DEL BERMEJO         CHACO       NEA
#
#        idproducto                          producto  idtipohorario  \
# 10             19                   Gas Oil Grado 2              2
# 11             19                   Gas Oil Grado 2              3
# 12             21                   Gas Oil Grado 3              2
# 13             21                   Gas Oil Grado 3              3
# 16              3  Nafta (premium) de más de 95 Ron              2
# ...           ...                               ...            ...
# 35973           3  Nafta (premium) de más de 95 Ron              3
# 35974           2   Nafta (súper) entre 92 y 95 Ron              2
# 35975           2   Nafta (súper) entre 92 y 95 Ron              3
# 35976           2   Nafta (súper) entre 92 y 95 Ron              2
# 35977           2   Nafta (súper) entre 92 y 95 Ron              3
#
#       tipohorario  precio      fecha_vigencia  idempresabandera  \
# 10         Diurno   54.39 2019-12-01 00:00:00                 2
# 11       Nocturno   54.39 2019-12-01 00:00:00                 2
# 12         Diurno   65.24 2019-12-01 00:00:00                 2
# 13       Nocturno   65.24 2019-12-01 00:00:00                 2
# 16         Diurno   67.26 2020-03-02 00:00:00                 2
# ...           ...     ...                 ...               ...
# 35973    Nocturno   63.25 2020-03-02 00:00:00                 2
# 35974      Diurno   54.48 2020-03-02 00:00:00                 2
# 35975    Nocturno   54.48 2020-03-02 00:00:00                 2
# 35976      Diurno   61.20 2020-04-30 10:01:00                 1
# 35977    Nocturno   61.20 2020-04-30 10:01:00                 1
#
#       empresabandera   latitud  longitud  \
# 10               YPF -33.67954 -65.46988
# 11               YPF -33.67954 -65.46988
# 12               YPF -33.67954 -65.46988
# 13               YPF -33.67954 -65.46988
# 16               YPF -33.67954 -65.46988
# ...              ...       ...       ...
# 35973            YPF -34.66054 -58.60785
# 35974            YPF -34.66054 -58.60785
# 35975            YPF -34.66054 -58.60785
# 35976         BLANCA -26.60249 -60.95301
# 35977         BLANCA -26.60249 -60.95301
#
#                                                  geojson
# 10     {"type":"Point","coordinates":[-65.46988,-33.6...
# 11     {"type":"Point","coordinates":[-65.46988,-33.6...
# 12     {"type":"Point","coordinates":[-65.46988,-33.6...
# 13     {"type":"Point","coordinates":[-65.46988,-33.6...
# 16     {"type":"Point","coordinates":[-65.46988,-33.6...
# ...                                                  ...
# 35973  {"type":"Point","coordinates":[-58.60785,-34.6...
# 35974  {"type":"Point","coordinates":[-58.60785,-34.6...
# 35975  {"type":"Point","coordinates":[-58.60785,-34.6...
# 35976  {"type":"Point","coordinates":[-60.95301,-26.6...
# 35977  {"type":"Point","coordinates":[-60.95301,-26.6...
#
# [22154 rows x 19 columns]

# %%
## Se reordena el dataset por fecha
df.sort_values('fecha_vigencia',inplace=True) 
df.reset_index(drop=True, inplace= True) 
df
# Out:
#       indice_tiempo  idempresa           cuit                         empresa  \
# 0           2018-07       1459  30-57345541-6                     ORAZI HNOS.
# 1           2018-07       1459  30-57345541-6                     ORAZI HNOS.
# 2           2018-07       1459  30-57345541-6                     ORAZI HNOS.
# 3           2018-07       1459  30-57345541-6                     ORAZI HNOS.
# 4           2018-07       2658  30-67162857-4            MORAN MANERA Y OTROS
# ...             ...        ...            ...                             ...
# 22149       2020-07       2447  30-68817343-0                    PEUMAN S.R.L
# 22150       2020-07       7786  30-71205709-9                   VIPETROL S.A.
# 22151       2020-07       7786  30-71205709-9                   VIPETROL S.A.
# 22152       2020-07       7456  30-66605870-0  VICENTE VARACALLI E HIJOS S.A.
# 22153       2020-07       7456  30-66605870-0  VICENTE VARACALLI E HIJOS S.A.
#
#                                  direccion  localidad     provincia    region  \
# 0                        AVDA. DE MAYO 990   AREQUITO      SANTA FE    CENTRO
# 1                        AVDA. DE MAYO 990   AREQUITO      SANTA FE    CENTRO
# 2                        AVDA. DE MAYO 990   AREQUITO      SANTA FE    CENTRO
# 3                        AVDA. DE MAYO 990   AREQUITO      SANTA FE    CENTRO
# 4                           UGARTE Y GARAY   CHARLONE  BUENOS AIRES  PAMPEANA
# ...                                    ...        ...           ...       ...
# 22149            RUTA NAC 205 Y AV PEREYRA  SALADILLO  BUENOS AIRES  PAMPEANA
# 22150           Ruta Nacional 205 Km 182.5  SALADILLO  BUENOS AIRES  PAMPEANA
# 22151           Ruta Nacional 205 Km 182.5  SALADILLO  BUENOS AIRES  PAMPEANA
# 22152  AV SAN MARTIN (RUTA 2) Y SAENZ PEÑA     LEZAMA  BUENOS AIRES  PAMPEANA
# 22153  AV SAN MARTIN (RUTA 2) Y SAENZ PEÑA     LEZAMA  BUENOS AIRES  PAMPEANA
#
#        idproducto                          producto  idtipohorario  \
# 0               3  Nafta (premium) de más de 95 Ron              2
# 1               2   Nafta (súper) entre 92 y 95 Ron              3
# 2               2   Nafta (súper) entre 92 y 95 Ron              2
# 3               3  Nafta (premium) de más de 95 Ron              3
# 4               3  Nafta (premium) de más de 95 Ron              2
# ...           ...                               ...            ...
# 22149           2   Nafta (súper) entre 92 y 95 Ron              3
# 22150           2   Nafta (súper) entre 92 y 95 Ron              3
# 22151           2   Nafta (súper) entre 92 y 95 Ron              2
# 22152           2   Nafta (súper) entre 92 y 95 Ron              2
# 22153           2   Nafta (súper) entre 92 y 95 Ron              3
#
#       tipohorario  precio      fecha_vigencia  idempresabandera  \
# 0          Diurno   38.99 2018-07-10 11:39:00                 4
# 1        Nocturno   36.99 2018-07-10 11:39:00                 4
# 2          Diurno   36.99 2018-07-10 11:39:00                 4
# 3        Nocturno   38.99 2018-07-10 11:39:00                 4
# 4          Diurno   39.17 2018-07-28 19:06:00                 1
# ...           ...     ...                 ...               ...
# 22149    Nocturno   59.98 2020-07-18 14:03:00                 4
# 22150    Nocturno   59.98 2020-07-18 14:04:00                 4
# 22151      Diurno   59.98 2020-07-18 14:04:00                 4
# 22152      Diurno   59.09 2020-07-18 22:00:00                 1
# 22153    Nocturno   59.09 2020-07-18 22:00:00                 1
#
#          empresabandera    latitud   longitud  \
# 0      SHELL C.A.P.S.A. -33.141390 -61.465880
# 1      SHELL C.A.P.S.A. -33.141390 -61.465880
# 2      SHELL C.A.P.S.A. -33.141390 -61.465880
# 3      SHELL C.A.P.S.A. -33.141390 -61.465880
# 4                BLANCA -34.672560 -63.369870
# ...                 ...        ...        ...
# 22149  SHELL C.A.P.S.A. -35.629240 -59.781532
# 22150  SHELL C.A.P.S.A. -35.629154 -59.782673
# 22151  SHELL C.A.P.S.A. -35.629154 -59.782673
# 22152            BLANCA -35.872110 -57.897140
# 22153            BLANCA -35.872110 -57.897140
#
#                                                  geojson
# 0      {"type":"Point","coordinates":[-61.46588,-33.1...
# 1      {"type":"Point","coordinates":[-61.46588,-33.1...
# 2      {"type":"Point","coordinates":[-61.46588,-33.1...
# 3      {"type":"Point","coordinates":[-61.46588,-33.1...
# 4      {"type":"Point","coordinates":[-63.36987,-34.6...
# ...                                                  ...
# 22149  {"type":"Point","coordinates":[-59.781532,-35....
# 22150  {"type":"Point","coordinates":[-59.782673,-35....
# 22151  {"type":"Point","coordinates":[-59.782673,-35....
# 22152  {"type":"Point","coordinates":[-57.89714,-35.8...
# 22153  {"type":"Point","coordinates":[-57.89714,-35.8...
#
# [22154 rows x 19 columns]

# %%
plt.figure(figsize=(20,6)) 
plt.plot(df.fecha_vigencia, df.precio)
plt.show()

# %%
#Observamos la fechas faltantes
df['date_check'] = df.fecha_vigencia.diff()
df.date_check.value_counts()
# Out:
# 0 days 00:00:00    18970
# 0 days 00:01:00     1170
# 0 days 00:02:00      301
# 0 days 00:03:00      153
# 0 days 00:04:00      103
#                    ...
# 2 days 00:00:00        1
# 3 days 20:01:00        1
# 0 days 04:11:00        1
# 0 days 14:09:00        1
# 2 days 05:43:00        1
# Name: date_check, Length: 591, dtype: int64

# %%
#Rellenamos la fechas faltantes
df = df.set_index("fecha_vigencia").resample("d").mean().reset_index()

# %%
df
# Out:
#     fecha_vigencia    idempresa  idproducto  idtipohorario     precio  \
# 0       2018-07-10  1459.000000    2.500000       2.500000  37.990000
# 1       2018-07-11          NaN         NaN            NaN        NaN
# 2       2018-07-12          NaN         NaN            NaN        NaN
# 3       2018-07-13          NaN         NaN            NaN        NaN
# 4       2018-07-14          NaN         NaN            NaN        NaN
# ..             ...          ...         ...            ...        ...
# 735     2020-07-14  7250.666667    8.083333       2.500000  57.504167
# 736     2020-07-15  3511.571429   10.000000       2.500000  60.618571
# 737     2020-07-16  6628.224490    9.020408       2.510204  60.725510
# 738     2020-07-17  7305.000000   12.000000       2.500000  65.145000
# 739     2020-07-18  4643.375000    8.750000       2.500000  57.202500
#
#      idempresabandera    latitud   longitud
# 0            4.000000 -33.141390 -61.465880
# 1                 NaN        NaN        NaN
# 2                 NaN        NaN        NaN
# 3                 NaN        NaN        NaN
# 4                 NaN        NaN        NaN
# ..                ...        ...        ...
# 735          2.916667 -34.391965 -60.204331
# 736          1.857143 -32.240223 -62.413441
# 737          2.285714 -33.249377 -60.717099
# 738          1.000000 -31.321339 -58.725318
# 739          3.250000 -33.954314 -65.200956
#
# [740 rows x 8 columns]

# %%
df.rename(columns={'fecha_vigencia':'fecha'}, inplace=True)
df=df[['fecha','precio']]
df
# Out:
#          fecha     precio
# 0   2018-07-10  37.990000
# 1   2018-07-11        NaN
# 2   2018-07-12        NaN
# 3   2018-07-13        NaN
# 4   2018-07-14        NaN
# ..         ...        ...
# 735 2020-07-14  57.504167
# 736 2020-07-15  60.618571
# 737 2020-07-16  60.725510
# 738 2020-07-17  65.145000
# 739 2020-07-18  57.202500
#
# [740 rows x 2 columns]

# %%
print(df.isna().sum())
df = df.interpolate()
print(df.isna().sum())
# Out:
# fecha       0
# precio    426
# dtype: int64
# fecha     0
# precio    0
# dtype: int64

# %%
plt.figure(figsize=(20,6))
plt.plot(df.fecha, df.precio)
plt.show()

# %%
promedio_diario=df.precio.rolling(window=7, center=True).mean()
promedio_diario
# Out:
# 0            NaN
# 1            NaN
# 2            NaN
# 3      38.186667
# 4      38.252222
#          ...
# 735    59.711000
# 736    59.441357
# 737          NaN
# 738          NaN
# 739          NaN
# Name: precio, Length: 740, dtype: float64

# %%
plt.figure(figsize=(20,6))
plt.plot(df.index, df.precio)
plt.plot(promedio_diario)
plt.show()

# %%
mensual=df.resample('M', on='fecha').mean() 
mensual.shape
# Out:
# (25, 1)

# %%
plt.figure(figsize=(15,6))
plt.plot(mensual) 
plt.title('Variacion del precio Mensual') 
plt.show()

# %%
promedio_mensual=mensual.precio.rolling(window=7, center=True).mean()
promedio_mensual
# Out:
# fecha
# 2018-07-31          NaN
# 2018-08-31          NaN
# 2018-09-30          NaN
# 2018-10-31    42.244690
# 2018-11-30    42.284734
# 2018-12-31    43.090202
# 2019-01-31    43.841409
# 2019-02-28    44.036948
# 2019-03-31    44.718896
# 2019-04-30    45.729200
# 2019-05-31    47.140050
# 2019-06-30    49.603287
# 2019-07-31    51.180193
# 2019-08-31    52.564121
# 2019-09-30    54.349203
# 2019-10-31    55.819139
# 2019-11-30    57.161788
# 2019-12-31    58.359876
# 2020-01-31    58.836827
# 2020-02-29    59.145134
# 2020-03-31    59.432448
# 2020-04-30    59.266314
# 2020-05-31          NaN
# 2020-06-30          NaN
# 2020-07-31          NaN
# Freq: M, Name: precio, dtype: float64

# %%
plt.figure(figsize=(15,6))
plt.plot(promedio_mensual)
plt.show()

# %% [markdown]
# ## Prueba de prediccion

# %%
diario=df.resample('d', on='fecha').mean() 
diario
# Out:
#                precio
# fecha
# 2018-07-10  37.990000
# 2018-07-11  38.055556
# 2018-07-12  38.121111
# 2018-07-13  38.186667
# 2018-07-14  38.252222
# ...               ...
# 2020-07-14  57.504167
# 2020-07-15  60.618571
# 2020-07-16  60.725510
# 2020-07-17  65.145000
# 2020-07-18  57.202500
#
# [740 rows x 1 columns]

# %%
diario=diario.precio
diario.head()
# Out:
# fecha
# 2018-07-10    37.990000
# 2018-07-11    38.055556
# 2018-07-12    38.121111
# 2018-07-13    38.186667
# 2018-07-14    38.252222
# Freq: D, Name: precio, dtype: float64

# %%
look_back=90*1 #uso 90 dias para predecir el valor siguiente

# %%
N=diario.shape[0]
X=np.zeros((N- look_back - 1, look_back))
y=np.zeros(N- look_back-1)
print(X.shape, y.shape)
# Out:
# (649, 90) (649,)

# %%
# LLenamos las funcion x e y

for i in range (X.shape[0]): 
    X[i,:]= diario.iloc[i:i+look_back]
    y[i]=diario.iloc[i+look_back]

# %%
N_train= 365*1- look_back
N_test=400

length_total= N_train + N_test + look_back 

X_train = X[:N_train,:]
y_train= y[:N_train]
print(X_train.shape, y_train.shape)

X_test= X[N_train:N_train+N_test,:]
y_test= y[N_train:N_train+N_test]
print(X_test.shape, y_test.shape)
# Out:
# (275, 90) (275,)
# (374, 90) (374,)

# %%
from sklearn.metrics import mean_squared_error
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor(n_estimators=100, random_state=42, n_jobs = 4).fit(X_train,y_train)

# %%
y_pred = rf.predict(X)
y_train_pred = rf.predict(X_train)
y_test_pred = rf.predict(X_test)

# %%
mean_squared_error(y_test, y_test_pred, squared=False)
# Out:
# 8.836354232551365

# %%
plt.figure(figsize=(16,8))
plt.plot(diario.index[:length_total], diario[:length_total],lw = 0.75, label = 'Serie Original')
plt.plot(diario.index[:N_train + look_back], diario[:N_train + look_back],'--', label = 'Usado para entrenar')
plt.plot(diario.index[look_back: look_back + N_train], y_train_pred,'-.',label = 'Predicho en Train')
plt.plot(diario.index[N_train+look_back+1: length_total], y_test_pred,'-.', lw = 4, label = 'Predicho en Test')
plt.legend()
plt.xlabel('Tiempo')
plt.ylabel('Temperatura (°C)')
plt.show()

# %%
plt.figure(figsize=(15,6))
plt.subplot(1,2,1)
plt.scatter(y_test,y_test_pred,alpha=0.3,color='firebrick')

plt.plot([y_test.min(), y_test.max()],
         [y_test.min(),y_test.max()], 
         'r--',linewidth=2)


plt.title('Comparar los testeado con lo predicho')
plt.xlabel('y_test')
plt.ylabel('y_test_pred') 


plt.subplot(1,2,2)
sns.histplot(y_train-y_train_pred, kde=True,label='Datos Train',stat='density',color='green')
sns.histplot(y_test-y_test_pred, kde=True,label='Datos Test',stat='density',color='orange')
plt.title('Distribucion del error')
plt.legend()

MSE=mean_squared_error(y_train,y_train_pred,squared=False)
MSE_test=mean_squared_error(y_test, y_test_pred, squared=False)
print('Error del train:',MSE)
print('Error del test:',MSE_test)

plt.show()
# Out:
# Error del train: 0.715599139617703
# Error del test: 8.836354232551365

# %%
from sklearn.neural_network import MLPRegressor 
rn_regre= MLPRegressor(max_iter=800, learning_rate='adaptive')
rn_regre.fit(X_train, y_train)
# Out:
# MLPRegressor(learning_rate='adaptive', max_iter=800)

# %%
y_pred=rn_regre.predict(X)
y_train_pred=rn_regre.predict(X_train) 
y_test_pred=rn_regre.predict(X_test)

# %%
rmse_test= mean_squared_error(y_test, y_test_pred, squared= False)
rmse_train= mean_squared_error(y_train, y_train_pred, squared=False) 
print(rmse_train)
print(rmse_test)
# Out:
# 2.159771665156526
# 3.273522958199904

# %%
plt.figure(figsize=(16,8))
plt.plot(diario.index[:length_total], diario[:length_total],lw = 0.75, label = 'Serie Original')
plt.plot(diario.index[:N_train + look_back], diario[:N_train + look_back],'--', label = 'Usado para entrenar')
plt.plot(diario.index[look_back: look_back + N_train], y_train_pred,'-.',label = 'Predicho en Train')
plt.plot(diario.index[N_train+look_back+1: length_total], y_test_pred,'-.', lw = 4, label = 'Predicho en Test')
plt.legend()
plt.xlabel('Tiempo')
plt.ylabel('Temperatura (°C)')
plt.show()

# %%
plt.figure(figsize=(15,6))
plt.subplot(1,2,1)
plt.scatter(y_test,y_test_pred,alpha=0.3,color='firebrick')

plt.plot([y_test.min(), y_test.max()],
         [y_test.min(),y_test.max()], 
         'r--',linewidth=2)


plt.title('Comparar los testeado con lo predicho')
plt.xlabel('y_test')
plt.ylabel('y_test_pred') 


plt.subplot(1,2,2)
sns.histplot(y_train-y_train_pred, kde=True,label='Datos Train',stat='density',color='green')
sns.histplot(y_test-y_test_pred, kde=True,label='Datos Test',stat='density',color='orange')
plt.title('Distribucion del error')
plt.legend()

MSE=mean_squared_error(y_train,y_train_pred,squared=False)
MSE_test=mean_squared_error(y_test, y_test_pred, squared=False)
print('Error del train:',MSE)
print('Error del test:',MSE_test)

plt.show()
# Out:
# Error del train: 2.159771665156526
# Error del test: 3.273522958199904

# %%
diario=df.resample('d', on='fecha').mean() 
diario
# Out:
#                precio
# fecha
# 2018-07-10  37.990000
# 2018-07-11  38.055556
# 2018-07-12  38.121111
# 2018-07-13  38.186667
# 2018-07-14  38.252222
# ...               ...
# 2020-07-14  57.504167
# 2020-07-15  60.618571
# 2020-07-16  60.725510
# 2020-07-17  65.145000
# 2020-07-18  57.202500
#
# [740 rows x 1 columns]

# %%
diario=diario['2020-01':'2020-12'] 
diario
# Out:
#                precio
# fecha
# 2020-01-01  62.063333
# 2020-01-02  59.652222
# 2020-01-03  60.172381
# 2020-01-04  57.285538
# 2020-01-05  59.909644
# ...               ...
# 2020-07-14  57.504167
# 2020-07-15  60.618571
# 2020-07-16  60.725510
# 2020-07-17  65.145000
# 2020-07-18  57.202500
#
# [200 rows x 1 columns]

# %%
plt.plot(diario)
